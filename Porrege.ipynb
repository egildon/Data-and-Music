# %%
import pandas as pd
import plotly.express as px
from plotly.subplots import make_subplots

# %%
# Import the data from CSV
gini_df = pd.read_csv("gini.csv") #Gini Coefficient (2018)
# The Gini coefficient measures the inequality among the values of a frequency distribution, such as levels of income. A Gini coefficient of 0 reflects perfect equality, where all income or wealth values are the same, while a Gini coefficient of 1 (or 100%) reflects maximal inequality among values, a situation where a single individual has all the income while all others have none.
#Taken from https://www.gapminder.org/data/


gini_dfn = gini_df.dropna()#drop na values

gini_dfni = gini_dfn.set_index('country') #Set the country index


partner_violence_df = pd.read_csv("partner_violence.csv") #World partner Violence statistics (2018)
#Ever-partnered women and girls subjected to physical and/or sexual violence by a current or former intimate partner in the previous 12 months (% ages 15–49)
#Taken from https://www.gapminder.org/data/

partner_violence_dfn = partner_violence_df.dropna()#drop na values
#partner_violence_dfn['country_'] = partner_violence_dfn.loc[:, 'country'] 

partner_violence_dfni = partner_violence_dfn.set_index('country', drop=False)


#Set Limit gini year

#gini_df = gini_df['2018']


partner_violence_dfni
# Out:
#                    country   2018
# country
# Afghanistan    Afghanistan 35.000
# Angola              Angola 25.000
# Albania            Albania  6.000
# Argentina        Argentina  4.000
# Armenia            Armenia  5.000
# ...                    ...    ...
# Vanuatu            Vanuatu 29.000
# Samoa                Samoa 18.000
# South Africa  South Africa 13.000
# Zambia              Zambia 28.000
# Zimbabwe          Zimbabwe 18.000
#
# [166 rows x 2 columns]

# %% [markdown]
# ### It seems Like the new country index is messing up the  whole shebang

# %%
gini_dfni['1800']
# Out:
# country
# Afghanistan    30.500
# Angola         57.700
# Albania        39.900
# Andorra        42.500
# UAE            39.800
#                 ...
# Samoa          40.700
# Yemen          49.800
# South Africa   35.200
# Zambia         52.100
# Zimbabwe       27.300
# Name: 1800, Length: 197, dtype: float64

# %%
# partner_violence_dfni.index
partner_violence_df
# Out:
#           country   2018
# 0     Afghanistan 35.000
# 1          Angola 25.000
# 2         Albania  6.000
# 3       Argentina  4.000
# 4         Armenia  5.000
# ..            ...    ...
# 161       Vanuatu 29.000
# 162         Samoa 18.000
# 163  South Africa 13.000
# 164        Zambia 28.000
# 165      Zimbabwe 18.000
#
# [166 rows x 2 columns]

# %%
#gini_dfni.index

# %%
#TODO Make all of these indexed dataframes work with all of the other methods

# %%
gini_dfn.head(2)
# Out:
#        country   1800   1801   1802   1803   1804   1805   1806   1807   1808  \
# 0  Afghanistan 30.500 30.500 30.500 30.500 30.500 30.500 30.500 30.500 30.500
# 1       Angola 57.700 57.700 57.700 57.700 57.700 57.700 57.700 57.700 57.700
#
#    ...   2041   2042   2043   2044   2045   2046   2047   2048   2049   2050
# 0  ... 38.200 38.200 38.200 38.200 38.200 38.200 38.200 38.200 38.200 38.200
# 1  ... 52.000 52.000 52.000 52.000 52.000 52.000 52.000 52.000 52.000 52.000
#
# [2 rows x 252 columns]

# %%
gini_dfn['2018']
# Out:
# 0     37.700
# 1     51.300
# 2     33.200
# 3     35.100
# 4     26.000
#        ...
# 192   38.700
# 193   36.700
# 194   63.300
# 195   57.100
# 196   47.200
# Name: 2018, Length: 197, dtype: float64

# %%
gini_dfns = gini_dfni['2018']
gg = gini_dfni['2018']

# %%
gg = pd.DataFrame(gg)
gg.head()
# Out:
#               2018
# country
# Afghanistan 37.700
# Angola      51.300
# Albania     33.200
# Andorra     35.100
# UAE         26.000

# %%
partner_violence_dfni.head(3)
# Out:
#                  country   2018
# country
# Afghanistan  Afghanistan 35.000
# Angola            Angola 25.000
# Albania          Albania  6.000

# %%
#me = list(gini_dfns)
#me_df = {""}
''
new_df = partner_violence_dfni.join(gg, lsuffix='_pviolence', rsuffix='_gini' )

# %%
new_df
# Out:
#                    country  2018_pviolence  2018_gini
# country
# Afghanistan    Afghanistan          35.000     37.700
# Angola              Angola          25.000     51.300
# Albania            Albania           6.000     33.200
# Argentina        Argentina           4.000     41.300
# Armenia            Armenia           5.000     34.400
# ...                    ...             ...        ...
# Vanuatu            Vanuatu          29.000     37.600
# Samoa                Samoa          18.000     38.700
# South Africa  South Africa          13.000     63.300
# Zambia              Zambia          28.000     57.100
# Zimbabwe          Zimbabwe          18.000     47.200
#
# [166 rows x 3 columns]

# %%
partner_violence_dfn.shape
# Out:
# (166, 2)

# %%
partner_violence_dfn.head(2)
# Out:
#        country   2018
# 0  Afghanistan 35.000
# 1       Angola 25.000

# %%
partner_violence_dfn.shape
# Out:
# (166, 2)

# %%
type(new_df)
# Out:
# pandas.core.frame.DataFrame

# %%
new_df['2018_gini']
new_df['country']
# Out:
# country
# Afghanistan      Afghanistan
# Angola                Angola
# Albania              Albania
# Argentina          Argentina
# Armenia              Armenia
#                     ...
# Vanuatu              Vanuatu
# Samoa                  Samoa
# South Africa    South Africa
# Zambia                Zambia
# Zimbabwe            Zimbabwe
# Name: country, Length: 166, dtype: object

# %% [markdown]
# # Null Hypothesis
#
# There is no correlation between the GINI scoring of a country and the reported percentages of partner violence reported in 2018.

# %% [markdown]
# # The Pearson Correlation test
#
# Pearson's correlation coefficient is the covariance of the two variables divided by the product of their standard deviations. The form of the definition involves a "product moment", that is, the mean (the first moment about the origin) of the product of the mean-adjusted random variables; hence the modifier product-moment in the name.
#
#
# In statistics, correlation or dependence is any statistical relationship, whether causal or not, between two random variables or bivariate data. Although in the broadest sense, "correlation" may indicate any type of association, in statistics it usually refers to the degree to which a pair of variables are linearly related.

# %%
new_df.corr(method='pearson', numeric_only = True).style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_8f36e_row0_col0, #T_8f36e_row1_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_8f36e_row0_col1, #T_8f36e_row1_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8f36e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f36e_level0_col0" class="col_heading level0 col0" >2018_pviolence</th>
#       <th id="T_8f36e_level0_col1" class="col_heading level0 col1" >2018_gini</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f36e_level0_row0" class="row_heading level0 row0" >2018_pviolence</th>
#       <td id="T_8f36e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8f36e_row0_col1" class="data row0 col1" >0.260442</td>
#     </tr>
#     <tr>
#       <th id="T_8f36e_level0_row1" class="row_heading level0 row1" >2018_gini</th>
#       <td id="T_8f36e_row1_col0" class="data row1 col0" >0.260442</td>
#       <td id="T_8f36e_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### GINI Score:
# Gini measures inequality: How large are the income differences within a society. First imagine you line up all people in a country, ordered by income: The poorest to the left and the richest to the right. Now you walk from the left to the right asking how much money they earn every year, and you add up the number. When you reach the middle, you have counted 50% of the people, but the richest half remains. The amount of income you have added up is much less than 50% of all the money, say , maybe 20%. Maybe 10%? If there are lots of people with low incomes, you will have added maybe 15% of the money for the poorest half of the population, but if the income differences are less extreme, the 50% poorest may earn 30% of the incomes. If everybody earns the same, you would have gotten to 50% of the money, after asking 50% of the people. In that case (which never happens), the gini is zero. No inequality. The opposite extreme case (which also never happens) would be that only the richest person has any income: one guy earns all the money.  Then the gini is 1. Perfect inequality. But most countries have a gini somewhere around 0.4, in-between these two extreme examples.

# %% [markdown]
# ### Partner Violence:
# Ever-partnered women and girls subjected to physical and/or sexual violence by a current or former intimate partner in the previous 12 months (% ages 15–49)

# %%
# Set sane display perameters
pd.set_option('display.float_format', lambda x: '%.3f' %x)
gini_dfn.describe().style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_d6c90">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6c90_level0_col0" class="col_heading level0 col0" >1800</th>
#       <th id="T_d6c90_level0_col1" class="col_heading level0 col1" >1801</th>
#       <th id="T_d6c90_level0_col2" class="col_heading level0 col2" >1802</th>
#       <th id="T_d6c90_level0_col3" class="col_heading level0 col3" >1803</th>
#       <th id="T_d6c90_level0_col4" class="col_heading level0 col4" >1804</th>
#       <th id="T_d6c90_level0_col5" class="col_heading level0 col5" >1805</th>
#       <th id="T_d6c90_level0_col6" class="col_heading level0 col6" >1806</th>
#       <th id="T_d6c90_level0_col7" class="col_heading level0 col7" >1807</th>
#       <th id="T_d6c90_level0_col8" class="col_heading level0 col8" >1808</th>
#       <th id="T_d6c90_level0_col9" class="col_heading level0 col9" >1809</th>
#       <th id="T_d6c90_level0_col10" class="col_heading level0 col10" >1810</th>
#       <th id="T_d6c90_level0_col11" class="col_heading level0 col11" >1811</th>
#       <th id="T_d6c90_level0_col12" class="col_heading level0 col12" >1812</th>
#       <th id="T_d6c90_level0_col13" class="col_heading level0 col13" >1813</th>
#       <th id="T_d6c90_level0_col14" class="col_heading level0 col14" >1814</th>
#       <th id="T_d6c90_level0_col15" class="col_heading level0 col15" >1815</th>
#       <th id="T_d6c90_level0_col16" class="col_heading level0 col16" >1816</th>
#       <th id="T_d6c90_level0_col17" class="col_heading level0 col17" >1817</th>
#       <th id="T_d6c90_level0_col18" class="col_heading level0 col18" >1818</th>
#       <th id="T_d6c90_level0_col19" class="col_heading level0 col19" >1819</th>
#       <th id="T_d6c90_level0_col20" class="col_heading level0 col20" >1820</th>
#       <th id="T_d6c90_level0_col21" class="col_heading level0 col21" >1821</th>
#       <th id="T_d6c90_level0_col22" class="col_heading level0 col22" >1822</th>
#       <th id="T_d6c90_level0_col23" class="col_heading level0 col23" >1823</th>
#       <th id="T_d6c90_level0_col24" class="col_heading level0 col24" >1824</th>
#       <th id="T_d6c90_level0_col25" class="col_heading level0 col25" >1825</th>
#       <th id="T_d6c90_level0_col26" class="col_heading level0 col26" >1826</th>
#       <th id="T_d6c90_level0_col27" class="col_heading level0 col27" >1827</th>
#       <th id="T_d6c90_level0_col28" class="col_heading level0 col28" >1828</th>
#       <th id="T_d6c90_level0_col29" class="col_heading level0 col29" >1829</th>
#       <th id="T_d6c90_level0_col30" class="col_heading level0 col30" >1830</th>
#       <th id="T_d6c90_level0_col31" class="col_heading level0 col31" >1831</th>
#       <th id="T_d6c90_level0_col32" class="col_heading level0 col32" >1832</th>
#       <th id="T_d6c90_level0_col33" class="col_heading level0 col33" >1833</th>
#       <th id="T_d6c90_level0_col34" class="col_heading level0 col34" >1834</th>
#       <th id="T_d6c90_level0_col35" class="col_heading level0 col35" >1835</th>
#       <th id="T_d6c90_level0_col36" class="col_heading level0 col36" >1836</th>
#       <th id="T_d6c90_level0_col37" class="col_heading level0 col37" >1837</th>
#       <th id="T_d6c90_level0_col38" class="col_heading level0 col38" >1838</th>
#       <th id="T_d6c90_level0_col39" class="col_heading level0 col39" >1839</th>
#       <th id="T_d6c90_level0_col40" class="col_heading level0 col40" >1840</th>
#       <th id="T_d6c90_level0_col41" class="col_heading level0 col41" >1841</th>
#       <th id="T_d6c90_level0_col42" class="col_heading level0 col42" >1842</th>
#       <th id="T_d6c90_level0_col43" class="col_heading level0 col43" >1843</th>
#       <th id="T_d6c90_level0_col44" class="col_heading level0 col44" >1844</th>
#       <th id="T_d6c90_level0_col45" class="col_heading level0 col45" >1845</th>
#       <th id="T_d6c90_level0_col46" class="col_heading level0 col46" >1846</th>
#       <th id="T_d6c90_level0_col47" class="col_heading level0 col47" >1847</th>
#       <th id="T_d6c90_level0_col48" class="col_heading level0 col48" >1848</th>
#       <th id="T_d6c90_level0_col49" class="col_heading level0 col49" >1849</th>
#       <th id="T_d6c90_level0_col50" class="col_heading level0 col50" >1850</th>
#       <th id="T_d6c90_level0_col51" class="col_heading level0 col51" >1851</th>
#       <th id="T_d6c90_level0_col52" class="col_heading level0 col52" >1852</th>
#       <th id="T_d6c90_level0_col53" class="col_heading level0 col53" >1853</th>
#       <th id="T_d6c90_level0_col54" class="col_heading level0 col54" >1854</th>
#       <th id="T_d6c90_level0_col55" class="col_heading level0 col55" >1855</th>
#       <th id="T_d6c90_level0_col56" class="col_heading level0 col56" >1856</th>
#       <th id="T_d6c90_level0_col57" class="col_heading level0 col57" >1857</th>
#       <th id="T_d6c90_level0_col58" class="col_heading level0 col58" >1858</th>
#       <th id="T_d6c90_level0_col59" class="col_heading level0 col59" >1859</th>
#       <th id="T_d6c90_level0_col60" class="col_heading level0 col60" >1860</th>
#       <th id="T_d6c90_level0_col61" class="col_heading level0 col61" >1861</th>
#       <th id="T_d6c90_level0_col62" class="col_heading level0 col62" >1862</th>
#       <th id="T_d6c90_level0_col63" class="col_heading level0 col63" >1863</th>
#       <th id="T_d6c90_level0_col64" class="col_heading level0 col64" >1864</th>
#       <th id="T_d6c90_level0_col65" class="col_heading level0 col65" >1865</th>
#       <th id="T_d6c90_level0_col66" class="col_heading level0 col66" >1866</th>
#       <th id="T_d6c90_level0_col67" class="col_heading level0 col67" >1867</th>
#       <th id="T_d6c90_level0_col68" class="col_heading level0 col68" >1868</th>
#       <th id="T_d6c90_level0_col69" class="col_heading level0 col69" >1869</th>
#       <th id="T_d6c90_level0_col70" class="col_heading level0 col70" >1870</th>
#       <th id="T_d6c90_level0_col71" class="col_heading level0 col71" >1871</th>
#       <th id="T_d6c90_level0_col72" class="col_heading level0 col72" >1872</th>
#       <th id="T_d6c90_level0_col73" class="col_heading level0 col73" >1873</th>
#       <th id="T_d6c90_level0_col74" class="col_heading level0 col74" >1874</th>
#       <th id="T_d6c90_level0_col75" class="col_heading level0 col75" >1875</th>
#       <th id="T_d6c90_level0_col76" class="col_heading level0 col76" >1876</th>
#       <th id="T_d6c90_level0_col77" class="col_heading level0 col77" >1877</th>
#       <th id="T_d6c90_level0_col78" class="col_heading level0 col78" >1878</th>
#       <th id="T_d6c90_level0_col79" class="col_heading level0 col79" >1879</th>
#       <th id="T_d6c90_level0_col80" class="col_heading level0 col80" >1880</th>
#       <th id="T_d6c90_level0_col81" class="col_heading level0 col81" >1881</th>
#       <th id="T_d6c90_level0_col82" class="col_heading level0 col82" >1882</th>
#       <th id="T_d6c90_level0_col83" class="col_heading level0 col83" >1883</th>
#       <th id="T_d6c90_level0_col84" class="col_heading level0 col84" >1884</th>
#       <th id="T_d6c90_level0_col85" class="col_heading level0 col85" >1885</th>
#       <th id="T_d6c90_level0_col86" class="col_heading level0 col86" >1886</th>
#       <th id="T_d6c90_level0_col87" class="col_heading level0 col87" >1887</th>
#       <th id="T_d6c90_level0_col88" class="col_heading level0 col88" >1888</th>
#       <th id="T_d6c90_level0_col89" class="col_heading level0 col89" >1889</th>
#       <th id="T_d6c90_level0_col90" class="col_heading level0 col90" >1890</th>
#       <th id="T_d6c90_level0_col91" class="col_heading level0 col91" >1891</th>
#       <th id="T_d6c90_level0_col92" class="col_heading level0 col92" >1892</th>
#       <th id="T_d6c90_level0_col93" class="col_heading level0 col93" >1893</th>
#       <th id="T_d6c90_level0_col94" class="col_heading level0 col94" >1894</th>
#       <th id="T_d6c90_level0_col95" class="col_heading level0 col95" >1895</th>
#       <th id="T_d6c90_level0_col96" class="col_heading level0 col96" >1896</th>
#       <th id="T_d6c90_level0_col97" class="col_heading level0 col97" >1897</th>
#       <th id="T_d6c90_level0_col98" class="col_heading level0 c

# %%
fig = px.scatter(new_df ,x = 'country', y=['2018_gini','2018_pviolence'])
fig.show()

# %%
import scipy.stats as stats
import numpy as np
from scipy.stats import f_oneway

# %% [markdown]
# #T Test

# %%
a = new_df['2018_gini']
b = new_df['2018_pviolence']

stats.ttest_ind(a,b)
# Out:
# TtestResult(statistic=30.528934038044323, pvalue=3.862082081014955e-98, df=330.0)

# %%
f_oneway(new_df['2018_gini'],new_df['2018_pviolence'])
# Out:
# F_onewayResult(statistic=932.0158134992607, pvalue=3.8620820810151835e-98)
