# %%
import pandas as pd
import plotly.express as px
from plotly.subplots import make_subplots

# %%
# Import the data from CSV


# The Gini coefficient measures the inequality among the values of a frequency distribution, such as levels of income. A Gini coefficient of 0 reflects perfect equality, where all income or wealth values are the same, while a Gini coefficient of 1 (or 100%) reflects maximal inequality among values, a situation where a single individual has all the income while all others have none.
#Taken from https://www.gapminder.org/data/
gini_df = pd.read_csv("gini.csv") #Gini Coefficient (2018)
gini_dfn = gini_df.dropna()#drop na values
gini_dfni = gini_dfn.set_index('country', drop=False) #Set the country index

#Ever-partnered women and girls subjected to physical and/or sexual violence by a current or former intimate partner in the previous 12 months (% ages 15–49)
#Taken from https://www.gapminder.org/data/
partner_violence_df = pd.read_csv("partner_violence.csv") #World partner Violence statistics (2018)
partner_violence_dfn = partner_violence_df.dropna()#drop na values
partner_violence_dfni = partner_violence_dfn.set_index('country', drop=False)

#importing GDP figures
#Taken from https://www.gapminder.org/data/
gdp_us_inflation_adjusted_df = pd.read_csv("gdppercapita_us_inflation_adjusted.csv") #ADJUSTED GDP PER CAPITA
gdp_us_inflation_adjusted_dfn = gdp_us_inflation_adjusted_df.dropna()#drop na values
gdp_us_inflation_adjusted_dfni = gdp_us_inflation_adjusted_dfn.set_index('country', drop=False)#Set the country index



# ,drop=False
#Set Limit gini year

#gini_df = gini_df['2018']


#partner_violence_dfni

gdp_us_inflation_adjusted_dfni.index
#gdp_us_inflation_adjusted_dfni[['country'],'2000']
gini_dfni['country']
# Out:
# country
# Afghanistan      Afghanistan
# Angola                Angola
# Albania              Albania
# Andorra              Andorra
# UAE                      UAE
#                     ...
# Samoa                  Samoa
# Yemen                  Yemen
# South Africa    South Africa
# Zambia                Zambia
# Zimbabwe            Zimbabwe
# Name: country, Length: 197, dtype: object

# %%
gdp_us_inflation_adjusted_dfni.index
# Out:
# Index(['Argentina', 'Australia', 'Austria', 'Burundi', 'Belgium', 'Benin',
#        'Burkina Faso', 'Bangladesh', 'Bahamas', 'Belize', 'Bermuda', 'Bolivia',
#        'Brazil', 'Botswana', 'Central African Republic', 'Chile', 'China',
#        'Cote d'Ivoire', 'Cameroon', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Colombia', 'Costa Rica', 'Denmark', 'Dominican Republic', 'Algeria',
#        'Ecuador', 'Egypt', 'Spain', 'Finland', 'Fiji', 'France', 'Gabon', 'UK',
#        'Ghana', 'Greece', 'Guatemala', 'Guyana', 'Honduras', 'Haiti',
#        'Indonesia', 'India', 'Iran', 'Italy', 'Japan', 'Kenya', 'South Korea',
#        'Lesotho', 'Luxembourg', 'Madagascar', 'Mexico', 'Malawi', 'Malaysia',
#        'Niger', 'Nigeria', 'Nicaragua', 'Netherlands', 'Norway', 'Nepal',
#        'Pakistan', 'Panama', 'Peru', 'Philippines', 'Papua New Guinea',
#        'Puerto Rico', 'Portugal', 'Paraguay', 'Rwanda', 'Sudan', 'Senegal',
# ...

# %% [markdown]
# #### Slicing the years 2000 to 2020

# %%
gini_dfnic = gini_dfni.loc[:,'2000':'2020'] #slicing required dates 2000 - 2020
gdp_us_inflation_adjusted_dfnic = gdp_us_inflation_adjusted_dfni.loc[:,'2000':'2020'] #slicing required dates 2000 - 2020

gini_dfnic2 = pd.DataFrame(gini_dfnic)

new2_df = gdp_us_inflation_adjusted_dfnic.join(gini_dfnic2, lsuffix = '_gini' , rsuffix='_gdp')
#new2_df['2011_gdp']
gdp_us_inflation_adjusted_dfnic.shape
# Out:
# (86, 21)

# %%
new2_df.shape
# Out:
# (86, 42)

# %%
gini_dfnic2.shape
# Out:
# (197, 21)

# %%
# Test View Field

gdp_us_inflation_adjusted_dfnic
# Out:
#                                  2000   2001   2002   2003   2004   2005  \
# country
# Argentina                       10.7k  10.1k   8900   9580  10.3k  11.1k
# Australia                       45.9k  46.2k  47.5k  48.5k    50k  50.9k
# Austria                         38.8k  39.2k  39.6k  39.8k  40.7k  41.3k
# Burundi                           310    309    313    300    303    295
# Belgium                         35.7k  35.9k  36.4k  36.6k  37.8k  38.4k
# ...                               ...    ...    ...    ...    ...    ...
# USA                             48.7k  48.7k  49.1k    50k  51.5k  52.8k
# St. Vincent and the Grenadines   5060   5150   5440   5820   6080   6270
# South Africa                     4740   4820   4950   5050   5230   5460
# Zambia                            815    833    844    875    907    941
# Zimbabwe                         1680   1690   1530   1260   1180   1110
#
#                                  2006   2007   2008   2009  ...   2011   2012  \
# ...

# %%
# partner_violence_dfni.index
partner_violence_df
# Out:
#           country  2018
# 0     Afghanistan  35.0
# 1          Angola  25.0
# 2         Albania   6.0
# 3       Argentina   4.0
# 4         Armenia   5.0
# ..            ...   ...
# 161       Vanuatu  29.0
# 162         Samoa  18.0
# 163  South Africa  13.0
# 164        Zambia  28.0
# 165      Zimbabwe  18.0
#
# [166 rows x 2 columns]

# %%
#gini_dfni.index

# %%
#TODO Make all of these indexed dataframes work with all of the other methods

# %%
gini_dfn.head(2)
# Out:
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0  Afghanistan  30.5  30.5  30.5  30.5  30.5  30.5  30.5  30.5  30.5  ...
# 1       Angola  57.7  57.7  57.7  57.7  57.7  57.7  57.7  57.7  57.7  ...
#
#    2041  2042  2043  2044  2045  2046  2047  2048  2049  2050
# 0  38.2  38.2  38.2  38.2  38.2  38.2  38.2  38.2  38.2  38.2
# 1  52.0  52.0  52.0  52.0  52.0  52.0  52.0  52.0  52.0  52.0
#
# [2 rows x 252 columns]

# %%
gini_dfn['2018']
# Out:
# 0      37.7
# 1      51.3
# 2      33.2
# 3      35.1
# 4      26.0
#        ...
# 192    38.7
# 193    36.7
# 194    63.3
# 195    57.1
# 196    47.2
# Name: 2018, Length: 197, dtype: float64

# %%
gini_dfns = gini_dfni['2018']
gini_mod = gini_dfni['2018']

# %%
gini_mod = pd.DataFrame(gini_mod)
gini_mod.head()
# Out:
#              2018
# country
# Afghanistan  37.7
# Angola       51.3
# Albania      33.2
# Andorra      35.1
# UAE          26.0

# %%
partner_violence_dfni.head(3)
# Out:
#                  country  2018
# country
# Afghanistan  Afghanistan  35.0
# Angola            Angola  25.0
# Albania          Albania   6.0

# %%
# new Dataframe with joined series and defined columns

new_df = partner_violence_dfni.join(gini_mod, lsuffix='_pviolence', rsuffix='_gini' )
# EVEN MORE DATAFRAMES

#new2_df = new_df.join(gdp_us_inflation_adjusted_dfnic, lsuffix = '_gini' , rsuffix='_gdp')

#new2_df = new_df.merge(gdp_us_inflation_adjusted_dfnic, suffixes = '_gdp') #Try using a for loop to resolve this, run a T test from 2000 to 2020

#new2_df.head(5)
#x = gdp_us_inflation_adjusted_dfnic.isna

gdp_us_inflation_adjusted_dfnic.head(3)
#gdp_us_inflation_adjusted_dfnic['country']
# Out:
#             2000   2001   2002   2003   2004   2005   2006   2007   2008  \
# country
# Argentina  10.7k  10.1k   8900   9580  10.3k  11.1k  11.9k  12.9k  13.2k
# Australia  45.9k  46.2k  47.5k  48.5k    50k  50.9k  51.6k  52.6k  53.4k
# Austria    38.8k  39.2k  39.6k  39.8k  40.7k  41.3k  42.5k  43.9k  44.4k
#
#             2009  ...   2011   2012   2013   2014   2015   2016   2017   2018  \
# country           ...
# Argentina  12.3k  ...  14.2k  13.9k  14.1k  13.6k  13.8k  13.4k  13.6k  13.1k
# Australia  53.3k  ...  54.1k  55.3k  55.7k  56.3k  56.7k  57.4k  57.7k  58.5k
# Austria    42.7k  ...  44.5k  44.5k  44.3k  44.2k  44.2k  44.6k  45.3k  46.2k
#
#             2019   2020
# country
# Argentina  12.7k  11.3k
# Australia  58.9k  58.1k
# Austria    46.6k  43.5k
#
# [3 rows x 21 columns]

# %%
new2_df.head
# Out:
# <bound method NDFrame.head of                                2000_gini 2001_gini 2002_gini 2003_gini  \
# country
# Argentina                          10.7k     10.1k      8900      9580
# Australia                          45.9k     46.2k     47.5k     48.5k
# Austria                            38.8k     39.2k     39.6k     39.8k
# Burundi                              310       309       313       300
# Belgium                            35.7k     35.9k     36.4k     36.6k
# ...                                  ...       ...       ...       ...
# USA                                48.7k     48.7k     49.1k       50k
# St. Vincent and the Grenadines      5060      5150      5440      5820
# South Africa                        4740      4820      4950      5050
# Zambia                               815       833       844       875
# Zimbabwe                            1680      1690      1530      1260
#
#                                2004_gini 2005_gini 2006_gini 2007_gini  \
# ...

# %%
new_df
new_df.head
# Out:
# <bound method NDFrame.head of                    country  2018_pviolence  2018_gini
# country
# Afghanistan    Afghanistan            35.0       37.7
# Angola              Angola            25.0       51.3
# Albania            Albania             6.0       33.2
# Argentina        Argentina             4.0       41.3
# Armenia            Armenia             5.0       34.4
# ...                    ...             ...        ...
# Vanuatu            Vanuatu            29.0       37.6
# Samoa                Samoa            18.0       38.7
# South Africa  South Africa            13.0       63.3
# Zambia              Zambia            28.0       57.1
# Zimbabwe          Zimbabwe            18.0       47.2
#
# [166 rows x 3 columns]>

# %%
gdp_us_inflation_adjusted_dfni.head(5)
# Out:
#              country   1960   1961   1962   1963   1964   1965   1966   1967  \
# country
# Argentina  Argentina   7410   7690   7500   6990   7570   8240   8060   8190
# Australia  Australia  19.9k    20k  19.8k  20.6k  21.7k  22.5k  22.5k  23.6k
# Austria      Austria  12.1k  12.6k  12.9k  13.4k  14.1k  14.5k  15.2k  15.5k
# Burundi      Burundi    291    245    260    265    274    277    283    314
# Belgium      Belgium  11.7k  12.3k  12.9k  13.3k  14.1k  14.5k  14.8k  15.3k
#
#             1968  ...   2012   2013   2014   2015   2016   2017   2018   2019  \
# country           ...
# Argentina   8450  ...  13.9k  14.1k  13.6k  13.8k  13.4k  13.6k  13.1k  12.7k
# Australia  24.4k  ...  55.3k  55.7k  56.3k  56.7k  57.4k  57.7k  58.5k  58.9k
# Austria    16.1k  ...  44.5k  44.3k  44.2k  44.2k  44.6k  45.3k  46.2k  46.6k
# Burundi      306  ...    301    305    308    289    283    278    274    270
# Belgium    15.9k  ...    40k    40k  40.4k    41k  41.3k  41.8k  42.4k  43.1k
#
# ...

# %%
partner_violence_dfn.shape
# Out:
# (166, 2)

# %%
partner_violence_dfn.head(2)
# Out:
#        country  2018
# 0  Afghanistan  35.0
# 1       Angola  25.0

# %%
partner_violence_dfn.shape
# Out:
# (166, 2)

# %%
type(new_df)
# Out:
# pandas.core.frame.DataFrame

# %%
new_df['2018_gini']
new_df['country']
# Out:
# country
# Afghanistan      Afghanistan
# Angola                Angola
# Albania              Albania
# Argentina          Argentina
# Armenia              Armenia
#                     ...
# Vanuatu              Vanuatu
# Samoa                  Samoa
# South Africa    South Africa
# Zambia                Zambia
# Zimbabwe            Zimbabwe
# Name: country, Length: 166, dtype: object

# %% [markdown]
# # Null Hypothesis
#
# There is no correlation between the GINI scoring of a country and the reported percentages of partner violence reported in 2018.

# %% [markdown]
# # The Pearson Correlation test
#
# Pearson's correlation coefficient is the covariance of the two variables divided by the product of their standard deviations. The form of the definition involves a "product moment", that is, the mean (the first moment about the origin) of the product of the mean-adjusted random variables; hence the modifier product-moment in the name.
#
#
# In statistics, correlation or dependence is any statistical relationship, whether causal or not, between two random variables or bivariate data. Although in the broadest sense, "correlation" may indicate any type of association, in statistics it usually refers to the degree to which a pair of variables are linearly related.

# %%
new2_df.corr(method='pearson', numeric_only = True).style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_d5e9f_row0_col0, #T_d5e9f_row1_col1, #T_d5e9f_row2_col2, #T_d5e9f_row3_col3, #T_d5e9f_row4_col4, #T_d5e9f_row5_col5, #T_d5e9f_row6_col6, #T_d5e9f_row7_col7, #T_d5e9f_row8_col8, #T_d5e9f_row9_col9, #T_d5e9f_row10_col10, #T_d5e9f_row11_col11, #T_d5e9f_row12_col12, #T_d5e9f_row13_col13, #T_d5e9f_row14_col14, #T_d5e9f_row15_col15, #T_d5e9f_row16_col16, #T_d5e9f_row17_col17, #T_d5e9f_row18_col18, #T_d5e9f_row19_col19, #T_d5e9f_row20_col20 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_d5e9f_row0_col1, #T_d5e9f_row1_col0, #T_d5e9f_row3_col2, #T_d5e9f_row9_col10 {
#   background-color: #e2e418;
#   color: #000000;
# }
# #T_d5e9f_row0_col2, #T_d5e9f_row3_col5, #T_d5e9f_row11_col14, #T_d5e9f_row18_col15 {
#   background-color: #bade28;
#   color: #000000;
# }
# #T_d5e9f_row0_col3, #T_d5e9f_row7_col3, #T_d5e9f_row9_col13, #T_d5e9f_row11_col16 {
#   background-color: #89d548;
#   color: #000000;
# }
# ...

# %% [markdown]
# ### GINI Score:
# Gini measures inequality: How large are the income differences within a society. First imagine you line up all people in a country, ordered by income: The poorest to the left and the richest to the right. Now you walk from the left to the right asking how much money they earn every year, and you add up the number. When you reach the middle, you have counted 50% of the people, but the richest half remains. The amount of income you have added up is much less than 50% of all the money, say , maybe 20%. Maybe 10%? If there are lots of people with low incomes, you will have added maybe 15% of the money for the poorest half of the population, but if the income differences are less extreme, the 50% poorest may earn 30% of the incomes. If everybody earns the same, you would have gotten to 50% of the money, after asking 50% of the people. In that case (which never happens), the gini is zero. No inequality. The opposite extreme case (which also never happens) would be that only the richest person has any income: one guy earns all the money.  Then the gini is 1. Perfect inequality. But most countries have a gini somewhere around 0.4, in-between these two extreme examples.

# %% [markdown]
# ### Partner Violence:
# Ever-partnered women and girls subjected to physical and/or sexual violence by a current or former intimate partner in the previous 12 months (% ages 15–49)

# %%
# Set sane display perameters
pd.set_option('display.float_format', lambda x: '%.3f' %x)
gini_dfn.describe().style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_3199b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3199b_level0_col0" class="col_heading level0 col0" >1800</th>
#       <th id="T_3199b_level0_col1" class="col_heading level0 col1" >1801</th>
#       <th id="T_3199b_level0_col2" class="col_heading level0 col2" >1802</th>
#       <th id="T_3199b_level0_col3" class="col_heading level0 col3" >1803</th>
#       <th id="T_3199b_level0_col4" class="col_heading level0 col4" >1804</th>
#       <th id="T_3199b_level0_col5" class="col_heading level0 col5" >1805</th>
#       <th id="T_3199b_level0_col6" class="col_heading level0 col6" >1806</th>
#       <th id="T_3199b_level0_col7" class="col_heading level0 col7" >1807</th>
#       <th id="T_3199b_level0_col8" class="col_heading level0 col8" >1808</th>
#       <th id="T_3199b_level0_col9" class="col_heading level0 col9" >1809</th>
# ...

# %%
fig = px.scatter(new_df ,x = 'country', y=['2018_gini','2018_pviolence'])
fig.show()

# %%
fig = px.scatter(new_df ,x = 'country', y=['2018_gini','2018_pviolence'])
fig.show()

# %%
import scipy.stats as stats
import numpy as np
from scipy.stats import f_oneway

# %% [markdown]
# # T-Test

# %%
gini_dfnic2.head(5)
# Out:
#               2000   2001   2002   2003   2004   2005   2006   2007   2008  \
# country
# Afghanistan 37.700 37.700 37.700 37.700 37.700 37.700 37.700 37.700 37.700
# Angola      52.000 50.700 49.500 48.300 47.100 46.000 44.900 43.800 42.700
# Albania     30.100 30.900 31.700 31.400 31.000 30.600 30.400 30.200 30.000
# Andorra     36.100 36.100 36.000 35.900 35.800 35.600 35.500 35.400 35.500
# UAE         32.200 32.200 32.100 32.000 31.900 32.000 31.800 32.100 32.300
#
#               2009  ...   2011   2012   2013   2014   2015   2016   2017  \
# country             ...
# Afghanistan 37.700  ... 37.700 37.700 37.700 37.700 37.700 37.700 37.700
# Angola      43.500  ... 45.100 46.000 46.800 47.700 48.500 49.400 50.300
# Albania     29.700  ... 29.200 29.000 31.600 34.600 32.900 33.700 33.200
# Andorra     35.500  ... 35.500 35.500 35.400 35.400 35.300 35.200 35.200
# UAE         32.600  ... 32.600 32.600 32.500 31.100 29.700 28.400 27.200
#
#               2018   2019   2020
# ...

# %%
a = new_df['2018_gini']
b = new_df['2018_pviolence']
c = gini_dfnic2


print(stats.ttest_ind(a,b))
# Out:
# TtestResult(statistic=30.528934038044323, pvalue=3.862082081014955e-98, df=330.0)

# %%
# attempt at a loop to test p value

#for i in range(1,len(columns)):
#    fig = plt.figure(figsize=(10,5))
#    sns.boxplot(x=st_data_2018_clean[columns[i]])
#    #print(i)

# %%
for columnx in c.columns:
        ax = (c['%s' %columnx] )
        print(stats.ttest_ind(ax,b))
# Out:
# TtestResult(statistic=32.29868768678889, pvalue=1.606321285630691e-108, df=361.0)
# TtestResult(statistic=32.491241218908854, pvalue=3.2493924008027676e-109, df=361.0)
# TtestResult(statistic=32.27453856876278, pvalue=1.963436757084654e-108, df=361.0)
# TtestResult(statistic=32.593187029742666, pvalue=1.3969223947556893e-109, df=361.0)
# TtestResult(statistic=32.92431973406456, pvalue=9.082866840231946e-111, df=361.0)
# TtestResult(statistic=33.09726505784006, pvalue=2.191166496592664e-111, df=361.0)
# TtestResult(statistic=32.806088522090675, pvalue=2.406233846989351e-110, df=361.0)
# TtestResult(statistic=32.9579778511377, pvalue=6.885092888612266e-111, df=361.0)
# TtestResult(statistic=32.89982720240048, pvalue=1.1112504278727162e-110, df=361.0)
# TtestResult(statistic=32.74883553611271, pvalue=3.8592549074111475e-110, df=361.0)
# TtestResult(statistic=32.66873183609319, pvalue=7.479188520221306e-110, df=361.0)
# ...

# %%
c['2000']
# Out:
# country
# Afghanistan    37.700
# Angola         52.000
# Albania        30.100
# Andorra        36.100
# UAE            32.200
#                 ...
# Samoa          40.700
# Yemen          34.900
# South Africa   57.800
# Zambia         45.500
# Zimbabwe       41.000
# Name: 2000, Length: 197, dtype: float64

# %%
f_oneway(new_df['2018_gini'],new_df['2018_pviolence'])
# Out:
# F_onewayResult(statistic=932.0158134992607, pvalue=3.8620820810151835e-98)

# %%
new2_df.head(5)
# Out:
#           2000_gini 2001_gini 2002_gini 2003_gini 2004_gini 2005_gini  \
# country
# Argentina     10.7k     10.1k      8900      9580     10.3k     11.1k
# Australia     45.9k     46.2k     47.5k     48.5k       50k     50.9k
# Austria       38.8k     39.2k     39.6k     39.8k     40.7k     41.3k
# Burundi         310       309       313       300       303       295
# Belgium       35.7k     35.9k     36.4k     36.6k     37.8k     38.4k
#
#           2006_gini 2007_gini 2008_gini 2009_gini  ... 2011_gdp 2012_gdp  \
# country                                            ...
# Argentina     11.9k     12.9k     13.2k     12.3k  ...   42.600   41.300
# Australia     51.6k     52.6k     53.4k     53.3k  ...   34.600   34.500
# Austria       42.5k     43.9k     44.4k     42.7k  ...   30.800   30.500
# Burundi         300       299       301       297  ...   37.000   37.800
# Belgium       39.1k     40.3k     40.2k       39k  ...   28.100   27.500
#
# ...
